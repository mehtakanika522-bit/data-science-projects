# %%
import numpy as mp
import pandas as pd

# %%
subs=pd.read_csv("/content/subs.csv")

# %%
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.sample()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 25876      125877           Arts     Sophomore             3.566
#
#        Weekly_GenAI_Hours     Primary_Use_Case Prompt_Engineering_Skill  \
# 25876                9.39  Summarizing_Reading                 Advanced
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 25876               4              False                      2.4
#
#        Perceived_AI_Dependency   Institutional_Policy  \
# 25876                        5  Allowed_With_Citation
#
#        Anxiety_Level_During_Exams  Post_Semester_GPA  Skill_Retention_Score  \
# 25876                           5              3.738                  63.91
#
#       Burnout_Risk_Level
# 25876             Medium

# %%
subs = pd.read_csv("/ai_student_impact_dataset (1).csv")

# %%
subs.value_counts()
# Out:
# Student_ID  Major_Category  Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  Primary_Use_Case           Prompt_Engineering_Skill  Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  Perceived_AI_Dependency  Institutional_Policy   Anxiety_Level_During_Exams  Post_Semester_GPA  Skill_Retention_Score  Burnout_Risk_Level
# 149984      Arts            Sophomore      3.245             1.42                Copywriting/Drafting       Beginner                  3               False              10.30                    3                        Actively_Encouraged    4                           3.385              85.93                  Medium                1
# ...

# %%
subs.count()
# Out:
# Student_ID                    50000
# Major_Category                50000
# Year_of_Study                 50000
# Pre_Semester_GPA              50000
# Weekly_GenAI_Hours            50000
# Primary_Use_Case              50000
# Prompt_Engineering_Skill      50000
# Tool_Diversity                50000
# Paid_Subscription             50000
# Traditional_Study_Hours       50000
# Perceived_AI_Dependency       50000
# Institutional_Policy          50000
# Anxiety_Level_During_Exams    50000
# Post_Semester_GPA             50000
# Skill_Retention_Score         50000
# Burnout_Risk_Level            50000
# dtype: int64

# %%
subs.sum()
# Out:
# Student_ID                                                           6250025000
# Major_Category                HumanitiesMedicalBusinessBusinessSTEMSTEMSTEMA...
# Year_of_Study                 SeniorJuniorFreshmanSeniorSophomoreJuniorFresh...
# Pre_Semester_GPA                                                     157305.117
# Weekly_GenAI_Hours                                                    421387.61
# Primary_Use_Case              Copywriting/DraftingIdeationSummarizing_Readin...
# Prompt_Engineering_Skill      BeginnerAdvancedBeginnerIntermediateAdvancedBe...
# Tool_Diversity                                                           140013
# Paid_Subscription                                                         21154
# Traditional_Study_Hours                                               560463.55
# Perceived_AI_Dependency                                                  175268
# Institutional_Policy          Allowed_With_CitationAllowed_With_CitationStri...
# ...

# %%
subs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  object
#  2   Year_of_Study               50000 non-null  object
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  object
#  6   Prompt_Engineering_Skill    50000 non-null  object
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  object
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
subs.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_586/3799989703.py in <cell line: 0>()
# ----> 1 subs.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
subs.mode()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001           STEM        Junior             3.433
# 1          100002            NaN           NaN               NaN
# 2          100003            NaN           NaN               NaN
# 3          100004            NaN           NaN               NaN
# 4          100005            NaN           NaN               NaN
# ...           ...            ...           ...               ...
# 49995      149996            NaN           NaN               NaN
# 49996      149997            NaN           NaN               NaN
# 49997      149998            NaN           NaN               NaN
# 49998      149999            NaN           NaN               NaN
# 49999      150000            NaN           NaN               NaN
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                    40.0  Debugging/Troubleshooting                 Beginner
# ...

# %%
subs.median(numeric_only=True)
# Out:
# Student_ID                    125000.500
# Pre_Semester_GPA                   3.210
# Weekly_GenAI_Hours                 5.800
# Tool_Diversity                     3.000
# Paid_Subscription                  0.000
# Traditional_Study_Hours           11.180
# Perceived_AI_Dependency            3.000
# Anxiety_Level_During_Exams         4.000
# Post_Semester_GPA                  3.421
# Skill_Retention_Score             76.000
# dtype: float64

# %%
subs.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# ...

# %%
subs.iloc[-1]
# Out:
# Student_ID                                   150000
# Major_Category                                 Arts
# Year_of_Study                             Sophomore
# Pre_Semester_GPA                              3.242
# Weekly_GenAI_Hours                              3.3
# Primary_Use_Case               Copywriting/Drafting
# Prompt_Engineering_Skill                   Beginner
# Tool_Diversity                                    1
# Paid_Subscription                             False
# Traditional_Study_Hours                        3.93
# Perceived_AI_Dependency                           2
# Institutional_Policy          Allowed_With_Citation
# Anxiety_Level_During_Exams                        6
# Post_Semester_GPA                             3.261
# Skill_Retention_Score                         76.16
# Burnout_Risk_Level                              Low
# Name: 49999, dtype: object

# %%
subs[5:15]
# Out:
#     Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 5       100006           STEM        Junior             3.449
# 6       100007           STEM      Freshman             3.622
# 7       100008           Arts        Junior             2.746
# 8       100009       Business     Sophomore             3.420
# 9       100010       Business     Sophomore             3.046
# 10      100011           STEM      Graduate             3.407
# 11      100012        Medical        Junior             2.627
# 12      100013           Arts        Senior             3.479
# 13      100014           STEM        Junior             3.225
# 14      100015           STEM      Freshman             3.202
#
#     Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 5                 6.50  Debugging/Troubleshooting                 Beginner
# 6                31.41        Summarizing_Reading                 Advanced
# ...

# %%
subs[-5:]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49995               12.16       Copywriting/Drafting                 Beginner
# 49996                2.51       Copywriting/Drafting             Intermediate
# 49997               15.87        Summarizing_Reading                 Advanced
# 49998               19.91  Debugging/Troubleshooting             Intermediate
# 49999                3.30       Copywriting/Drafting                 Beginner
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# ...

# %%
subs[::2]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 2          100003       Business      Freshman             3.398
# 4          100005           STEM     Sophomore             3.635
# 6          100007           STEM      Freshman             3.622
# 8          100009       Business     Sophomore             3.420
# ...           ...            ...           ...               ...
# 49990      149991       Business        Senior             2.970
# 49992      149993       Business      Graduate             2.829
# 49994      149995     Humanities        Senior             3.556
# 49996      149997           STEM        Senior             2.870
# 49998      149999       Business        Junior             3.398
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
subs.loc[[3,4,5]]
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
# 5      100006           STEM        Junior             3.449
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
# 5                6.50  Debugging/Troubleshooting                 Beginner
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 3               4              False                    15.23
# 4               4              False                    12.55
# 5               1              False                    14.19
#
#    Perceived_AI_Dependency   Institutional_Policy  Anxiety_Level_During_Exams  \
# 3                        2  Allowed_With_Citation                           2
# ...

# %%
subs_series = subs['Student_ID']
subs_series[1] = 100
subs_series
# Out:
# /tmp/ipykernel_586/2505657200.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subs_series[1] = 100
# 0        100001
# 1           100
# 2        100003
# 3        100004
# 4        100005
#           ...
# 49995    149996
# 49996    149997
# 49997    149998
# 49998    149999
# 49999    150000
# Name: Student_ID, Length: 50000, dtype: int64

# %%
subs_series[1]

# %%
subs_series['Prompt_Engineering_Skill'] =100
# Out:
# /tmp/ipykernel_586/2117723769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subs_series['Prompt_Engineering_Skill'] =100

# %%
subs_ser[2:4] = [100,100]
subs_ser

# %%
subs[2:5] =100
subs
# Out:
# /tmp/ipykernel_586/3142550873.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '100' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   subs[2:5] =100
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1             100        Medical        Junior             3.821
# 2             100            100           100           100.000
# 3             100            100           100           100.000
# 4             100            100           100           100.000
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# ...
